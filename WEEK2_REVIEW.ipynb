# %%
#seaborn패키지 불러오기
import seaborn as sns

# %%
#타이타닉 데이터 가져오기
tt=sns.load_dataset('titanic')

# %%
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # pandas 기초 문법

# %%
import pandas as pd

# %%
#titanic데이터는 데이터프레임 형태
type(tt)
# Out:
# pandas.core.frame.DataFrame

# %%
type(tt.pclass)#시리즈 형태
# Out:
# pandas.core.series.Series

# %%
type(tt.survived)#시리즈 형태
# Out:
# pandas.core.series.Series

# %%
type(tt.loc[0])#시리즈 형태
# Out:
# pandas.core.series.Series

# %%
tt.loc[0]
# Out:
# survived                 0
# pclass                   3
# sex                   male
# age                   22.0
# sibsp                    1
# parch                    0
# fare                  7.25
# embarked                 S
# class                Third
# who                    man
# adult_male            True
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                False
# Name: 0, dtype: object

# %%
tt.shape#행과 열을 반환
# Out:
# (891, 15)

# %%
tt.columns#칼럼만 추출
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
tt_col=list(tt.columns)#칼럼을 추출하여 리스트에 넣음
tt_col
# Out:
# ['survived',
#  'pclass',
#  'sex',
#  'age',
#  'sibsp',
#  'parch',
#  'fare',
#  'embarked',
#  'class',
#  'who',
#  'adult_male',
#  'deck',
#  'embark_town',
#  'alive',
#  'alone']

# %%
#데이터타입의 정보
tt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
tt.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
#수치형데이터 기초통계
tt.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#수치형이 아닌 데이터도 존재함
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#수치형 외 데이터까지 모두 확인
tt.describe(include='all')
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# ...

# %%
#디폴트는 앞의 5개 값을 추출
tt.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#개수 지정가능
tt.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %%
tt.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
tt.tail(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 881         0       3    male  33.0      0      0   7.8958        S   Third
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 881    man        True  NaN  Southampton    no   True
# ...

# %% [markdown]
# # 행과 열로 이뤄진 데이터프레임

# %% [markdown]
# #    열기준으로 데이터 추출하기
# # -df[컬럼명]
# # -df.컬럼명

# %%
#데이터 컬럼 하나만 추출
tt['survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64

# %%
#데이터 컬럼 여러개 추출 가능
tt[['survived','age']]
# Out:
#      survived   age
# 0           0  22.0
# 1           1  38.0
# 2           1  26.0
# 3           1  35.0
# 4           0  35.0
# ..        ...   ...
# 886         0  27.0
# 887         1  19.0
# 888         0   NaN
# 889         1  26.0
# 890         0  32.0
#
# [891 rows x 2 columns]

# %%
#추출한 데이터 컬럼도 변수처럼 사용 가능
tt_sp=tt[['age','survived','fare']]

# %%
tt_sp
# Out:
#       age  survived     fare
# 0    22.0         0   7.2500
# 1    38.0         1  71.2833
# 2    26.0         1   7.9250
# 3    35.0         1  53.1000
# 4    35.0         0   8.0500
# ..    ...       ...      ...
# 886  27.0         0  13.0000
# 887  19.0         1  30.0000
# 888   NaN         0  23.4500
# 889  26.0         1  30.0000
# 890  32.0         0   7.7500
#
# [891 rows x 3 columns]

# %% [markdown]
# #    행기준으로 데이터 추출하기
# # loc:레이블 이름으로 접근
# # iloc:인덱스 번호로 접근(숫자)

# %%
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.loc[0]
# Out:
# survived                 0
# pclass                   3
# sex                   male
# age                   22.0
# sibsp                    1
# parch                    0
# fare                  7.25
# embarked                 S
# class                Third
# who                    man
# adult_male            True
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                False
# Name: 0, dtype: object

# %%
tt.iloc[100]
# Out:
# survived                 0
# pclass                   3
# sex                 female
# age                   28.0
# sibsp                    0
# parch                    0
# fare                7.8958
# embarked                 S
# class                Third
# who                  woman
# adult_male           False
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                 True
# Name: 100, dtype: object

# %%
#-1 맨끝값
#loc는 -1 출력 불가
tt.loc[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/range.py:385, in RangeIndex.get_loc(self, key, method, tolerance)
#     384 try:
# --> 385     return self._range.index(new_key)
#     386 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [39], in <cell line: 3>()
#       1 #-1 맨끝값
#       2 #loc는 -1 출력 불가
# ----> 3 tt.loc[-1]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...

# %%
#iloc는 -1출력 가능
tt.iloc[-1]
# Out:
# survived                0
# pclass                  3
# sex                  male
# age                  32.0
# sibsp                   0
# parch                   0
# fare                 7.75
# embarked                Q
# class               Third
# who                   man
# adult_male           True
# deck                  NaN
# embark_town    Queenstown
# alive                  no
# alone                True
# Name: 890, dtype: object

# %%
tt.shape
# Out:
# (891, 15)

# %%
num_low=tt.shape[0]

# %%
last_idx=num_low-1

# %%
#loc로 맨끝값 툴력
tt.loc[last_idx]
# Out:
# survived                 0
# pclass                   3
# sex                   male
# age                   22.0
# sibsp                    1
# parch                    0
# fare                  7.25
# embarked                 S
# class                Third
# who                    man
# adult_male            True
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                False
# Name: 0, dtype: object

# %%
mid_num=75

# %%
tt.loc[mid_num]
# Out:
# survived                 0
# pclass                   3
# sex                   male
# age                   25.0
# sibsp                    0
# parch                    0
# fare                  7.65
# embarked                 S
# class                Third
# who                    man
# adult_male            True
# deck                     F
# embark_town    Southampton
# alive                   no
# alone                 True
# Name: 75, dtype: object

# %%
tt.iloc[mid_num]
# Out:
# survived                 0
# pclass                   3
# sex                   male
# age                   25.0
# sibsp                    0
# parch                    0
# fare                  7.65
# embarked                 S
# class                Third
# who                    man
# adult_male            True
# deck                     F
# embark_town    Southampton
# alive                   no
# alone                 True
# Name: 75, dtype: object

# %% [markdown]
#     여러 행을 추출할 때 리스트에 담기
#     [[index1,index2.......indexn]]

# %%
tt.loc[[1,50,100,150,200]]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 50          0       3    male   7.0      4      1  39.6875        S   Third
# 100         0       3  female  28.0      0      0   7.8958        S   Third
# 150         0       2    male  51.0      0      0  12.5250        S  Second
# 200         0       3    male  28.0      0      0   9.5000        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 50   child       False  NaN  Southampton    no  False
# 100  woman       False  NaN  Southampton    no   True
# 150    man        True  NaN  Southampton    no   True
# 200    man        True  NaN  Southampton    no   True

# %%
tt.iloc[[1,50,100,150,200]]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 50          0       3    male   7.0      4      1  39.6875        S   Third
# 100         0       3  female  28.0      0      0   7.8958        S   Third
# 150         0       2    male  51.0      0      0  12.5250        S  Second
# 200         0       3    male  28.0      0      0   9.5000        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 50   child       False  NaN  Southampton    no  False
# 100  woman       False  NaN  Southampton    no   True
# 150    man        True  NaN  Southampton    no   True
# 200    man        True  NaN  Southampton    no   True

# %% [markdown]
# #    슬라이싱
# # [시작점:끝점:증가폭]
# # [:]=>전체

# %%
tt.loc[:]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.loc[::2]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.loc[::5]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 15          1       2  female  55.0      0      0  16.0000        S  Second
# 20          0       2    male  35.0      0      0  26.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 870         0       3    male  26.0      0      0   7.8958        S   Third
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.iloc[:]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.iloc[::5]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 15          1       2  female  55.0      0      0  16.0000        S  Second
# 20          0       2    male  35.0      0      0  26.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 870         0       3    male  26.0      0      0   7.8958        S   Third
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt_sp_idx=tt.iloc[0:100:10]

# %%
#슬라이싱 값 변수에 넣을 수 있음
tt_sp_idx
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 20         0       2    male  35.0      0      0  26.0000        S  Second
# 30         0       1    male  40.0      0      0  27.7208        C   First
# 40         0       3  female  40.0      1      0   9.4750        S   Third
# 50         0       3    male   7.0      4      1  39.6875        S   Third
# 60         0       3    male  22.0      0      0   7.2292        C   Third
# 70         0       2    male  32.0      0      0  10.5000        S  Second
# 80         0       3    male  22.0      0      0   9.0000        S   Third
# 90         0       3    male  29.0      0      0   8.0500        S   Third
#
#       who  adult_male deck  embark_town alive  alone
# 0     man        True  NaN  Southampton    no  False
# ...

# %%
#loc는 끝값도 포함
tt.loc[1:10:3]
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1          1       1  female  38.0      1      0  71.2833        C  First
# 4          0       3    male  35.0      0      0   8.0500        S  Third
# 7          0       3    male   2.0      3      1  21.0750        S  Third
# 10         1       3  female   4.0      1      1  16.7000        S  Third
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 4     man        True  NaN  Southampton    no   True
# 7   child       False  NaN  Southampton    no  False
# 10  child       False    G  Southampton   yes  False

# %%
#iloc는 끝값 포함 X
tt.iloc[1:10:3]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 7         0       3    male   2.0      3      1  21.0750        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 1  woman       False    C    Cherbourg   yes  False
# 4    man        True  NaN  Southampton    no   True
# 7  child       False  NaN  Southampton    no  False

# %%
tt.iloc[0:12:3]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 3  woman       False    C  Southampton   yes  False
# 6    man        True    E  Southampton    no   True
# 9  child       False  NaN    Cherbourg   yes  False

# %%
tt.loc[0:12:3]
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 12         0       3    male  20.0      0      0   8.0500        S   Third
#
#       who  adult_male deck  embark_town alive  alone
# 0     man        True  NaN  Southampton    no  False
# 3   woman       False    C  Southampton   yes  False
# 6     man        True    E  Southampton    no   True
# 9   child       False  NaN    Cherbourg   yes  False
# 12    man        True  NaN  Southampton    no   True

# %%
tt_sp_idx
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 20         0       2    male  35.0      0      0  26.0000        S  Second
# 30         0       1    male  40.0      0      0  27.7208        C   First
# 40         0       3  female  40.0      1      0   9.4750        S   Third
# 50         0       3    male   7.0      4      1  39.6875        S   Third
# 60         0       3    male  22.0      0      0   7.2292        C   Third
# 70         0       2    male  32.0      0      0  10.5000        S  Second
# 80         0       3    male  22.0      0      0   9.0000        S   Third
# 90         0       3    male  29.0      0      0   8.0500        S   Third
#
#       who  adult_male deck  embark_town alive  alone
# 0     man        True  NaN  Southampton    no  False
# ...

# %%
#슬라이싱 후 인덱스 그대로 유지
tt_sp_idx.loc[1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/range.py:385, in RangeIndex.get_loc(self, key, method, tolerance)
#     384 try:
# --> 385     return self._range.index(new_key)
#     386 except ValueError as err:
#
# ValueError: 1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [83], in <cell line: 2>()
#       1 #슬라이싱 후 인덱스 그대로 유지
# ----> 2 tt_sp_idx.loc[1]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...

# %%
#슬라이싱한 데이터프레임에서 다시 인덱싱
tt_sp_idx.iloc[1]
# Out:
# survived                 1
# pclass                   3
# sex                 female
# age                    4.0
# sibsp                    1
# parch                    1
# fare                  16.7
# embarked                 S
# class                Third
# who                  child
# adult_male           False
# deck                     G
# embark_town    Southampton
# alive                  yes
# alone                False
# Name: 10, dtype: object

# %%
tt_sp_idx.loc[10]
# Out:
# survived                 1
# pclass                   3
# sex                 female
# age                    4.0
# sibsp                    1
# parch                    1
# fare                  16.7
# embarked                 S
# class                Third
# who                  child
# adult_male           False
# deck                     G
# embark_town    Southampton
# alive                  yes
# alone                False
# Name: 10, dtype: object

# %% [markdown]
# # 슬라이싱과 칼럼접근 동시에

# %%
tt.loc[1:20:2,['age']]
# Out:
#      age
# 1   38.0
# 3   35.0
# 5    NaN
# 7    2.0
# 9   14.0
# 11  58.0
# 13  39.0
# 15  55.0
# 17   NaN
# 19   NaN

# %%
tt.loc[1:20,['age']]
# Out:
#      age
# 1   38.0
# 2   26.0
# 3   35.0
# 4   35.0
# 5    NaN
# 6   54.0
# 7    2.0
# 8   27.0
# 9   14.0
# 10   4.0
# 11  58.0
# 12  20.0
# 13  39.0
# 14  14.0
# 15  55.0
# 16   2.0
# 17   NaN
# 18  31.0
# 19   NaN
# 20  35.0

# %%
#데이터프레임형태로 반환
type(tt.loc[1:50,['age']])
# Out:
# pandas.core.frame.DataFrame

# %%
tt.loc[1:10,'age']
# Out:
# 1     38.0
# 2     26.0
# 3     35.0
# 4     35.0
# 5      NaN
# 6     54.0
# 7      2.0
# 8     27.0
# 9     14.0
# 10     4.0
# Name: age, dtype: float64

# %%
#시리즈 형태로 반환
type(tt.loc[1:50,'age'])
# Out:
# pandas.core.series.Series

# %%
tt.loc[1:10,['age','survived']]
# Out:
#      age  survived
# 1   38.0         1
# 2   26.0         1
# 3   35.0         1
# 4   35.0         0
# 5    NaN         0
# 6   54.0         0
# 7    2.0         0
# 8   27.0         1
# 9   14.0         1
# 10   4.0         1

# %%
tt.iloc[1:10,[3,4,-1]]
# Out:
#     age  sibsp  alone
# 1  38.0      1  False
# 2  26.0      0   True
# 3  35.0      1  False
# 4  35.0      0   True
# 5   NaN      0   True
# 6  54.0      0   True
# 7   2.0      3  False
# 8  27.0      0  False
# 9  14.0      1  False

# %%
#iloc는 인덱스 번호로만 지정하여 접근 가능
tt.iloc[1:10,['age']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [151], in <cell line: 2>()
#       1 #iloc는 인덱스 번호로만 지정하여 접근 가능
# ----> 2 tt.iloc[1:10,['age']]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1458, in _iLocIndexer._getitem_tuple(self, tup)
#    1456 def _getitem_tuple(self, tup: tuple):
# -> 1458     tup = self._validate_tuple_indexer(tup)
#    1459     with suppress(IndexingError):
#    1460         return self._getitem_lowerdim(tup)
#
# ...

# %%
tt.iloc[1:10,[3,4,-1]]['age']
# Out:
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5     NaN
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# Name: age, dtype: float64

# %%
df=tt.iloc[1:10,[3,4,-1]]['age'].loc[1]
df
# Out:
# 38.0

# %% [markdown]
# # tt에서 인덱스 3번째 값 중에서 age와 class를 추출하는 다양한 방법

# %%
#1
tt.loc[3][['age','pclass']]
# Out:
# age       35.0
# pclass       1
# Name: 3, dtype: object

# %%
#2
tt[['age','pclass']].loc[3]
# Out:
# age       35.0
# pclass     1.0
# Name: 3, dtype: float64

# %%
#3
tt.loc[3,['age','pclass']]
# Out:
# age       35.0
# pclass       1
# Name: 3, dtype: object

# %%
#4
tt.iloc[3,[3,1]]
# Out:
# age       35.0
# pclass       1
# Name: 3, dtype: object

# %%
tt.loc[3]
# Out:
# survived                 1
# pclass                   1
# sex                 female
# age                   35.0
# sibsp                    1
# parch                    0
# fare                  53.1
# embarked                 S
# class                First
# who                  woman
# adult_male           False
# deck                     C
# embark_town    Southampton
# alive                  yes
# alone                False
# Name: 3, dtype: object

# %%
type(tt.loc[3])
# Out:
# pandas.core.series.Series

# %%
tt.loc[3].age
# Out:
# 35.0

# %%
tt.loc[3]['age']
# Out:
# 35.0

# %%
tt.iloc[3][3]
# Out:
# 35.0

# %%
type(tt.loc[1:10])
# Out:
# pandas.core.frame.DataFrame

# %%
type(tt.loc[3])
# Out:
# pandas.core.series.Series

# %%
#데이터프레임에서 loc는 칼럼명으로만 접근가능
tt.loc[1:10][3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 3
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
#시리즈 형태이므로 인덱스번호로도 접근가능
tt.loc[3][3]
# Out:
# 35.0

# %%
tt.iloc[1:10,[3,4]]
# Out:
#     age  sibsp
# 1  38.0      1
# 2  26.0      0
# 3  35.0      1
# 4  35.0      0
# 5   NaN      0
# 6  54.0      0
# 7   2.0      3
# 8  27.0      0
# 9  14.0      1

# %%
#에러나는 이유: loc는 칼럼명으로 접근해야 함 인덱스 번호로 X
tt.loc[1:10,[3,4]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [144], in <cell line: 2>()
#       1 #에러나는 이유: loc는 칼럼명으로 접근해야 함 인덱스 번호로 X
# ----> 2 tt.loc[1:10,[3,4]]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1149, in _LocIndexer._getitem_tuple(self, tup)
#    1146 if self._multi_take_opportunity(tup):
#    1147     return self._multi_take(tup)
# -> 1149 return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
#range를 이용하여 데이터 추출
rn=list(range(0,20,2))

# %%
#변수를 인덱스처럼 넣을 수 있음
tt.iloc[rn]
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0          0       3    male  22.0      1      0   7.2500        S  Third
# 2          1       3  female  26.0      0      0   7.9250        S  Third
# 4          0       3    male  35.0      0      0   8.0500        S  Third
# 6          0       1    male  54.0      0      0  51.8625        S  First
# 8          1       3  female  27.0      0      2  11.1333        S  Third
# 10         1       3  female   4.0      1      1  16.7000        S  Third
# 12         0       3    male  20.0      0      0   8.0500        S  Third
# 14         0       3  female  14.0      0      0   7.8542        S  Third
# 16         0       3    male   2.0      4      1  29.1250        Q  Third
# 18         0       3  female  31.0      1      0  18.0000        S  Third
#
#       who  adult_male deck  embark_town alive  alone
# 0     man        True  NaN  Southampton    no  False
# ...

# %%
rn_2=list(range(0,5))
#range를 이용하여 원하는 칼럼만 데이터 추출 가능
tt.iloc[:,rn_2]
# Out:
#      survived  pclass     sex   age  sibsp
# 0           0       3    male  22.0      1
# 1           1       1  female  38.0      1
# 2           1       3  female  26.0      0
# 3           1       1  female  35.0      1
# 4           0       3    male  35.0      0
# ..        ...     ...     ...   ...    ...
# 886         0       2    male  27.0      0
# 887         1       1  female  19.0      0
# 888         0       3  female   NaN      1
# 889         1       1    male  26.0      0
# 890         0       3    male  32.0      0
#
# [891 rows x 5 columns]

# %% [markdown]
# # 기본 통계치

# %%
tt['fare'].mean()
# Out:
# 32.2042079685746

# %%
tt.fare.mean()
# Out:
# 32.2042079685746

# %%
tt.fare.sum()
# Out:
# 28693.9493

# %%
tt.fare.count()
# Out:
# 891

# %%
tt.fare.median()
# Out:
# 14.4542

# %%
sum=tt.fare.sum()
count=tt.fare.count()
mean=sum/count
mean
# Out:
# 32.204207968574636

# %%
#pclass별로 평균 fare은?
#groupby 그룹으로 묶어서 계산
tt.groupby('pclass')['fare'].mean()
# Out:
# pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: fare, dtype: float64

# %%
tt.groupby('sex')['fare'].mean()
# Out:
# sex
# female    44.479818
# male      25.523893
# Name: fare, dtype: float64

# %%
tt.groupby('embark_town')['fare'].mean()
# Out:
# embark_town
# Cherbourg      59.954144
# Queenstown     13.276030
# Southampton    27.079812
# Name: fare, dtype: float64

# %%
tt.groupby('pclass')['survived'].mean()
# Out:
# pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: survived, dtype: float64

# %%
tt.groupby('sex')['pclass'].mean()
# Out:
# sex
# female    2.159236
# male      2.389948
# Name: pclass, dtype: float64

# %%
tt.groupby('sex')['fare'].mean()
# Out:
# sex
# female    44.479818
# male      25.523893
# Name: fare, dtype: float64

# %%
tt.groupby('sex')['age'].mean()
# Out:
# sex
# female    27.915709
# male      30.726645
# Name: age, dtype: float64
